# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression, Ridge, Lasso
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error
from statsmodels.stats.outliers_influence import variance_inflation_factor
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV, train_test_split

# %% [markdown]
# <h2 align="center" style="color:blue">Data Loading</h2>

# %%
df = pd.read_excel("premiums.xlsx")
df.head(3)
# Out:
#    Age  Gender     Region Marital_status  Number Of Dependants BMI_Category  \
# 0   26    Male  Northwest      Unmarried                     0       Normal
# 1   29  Female  Southeast        Married                     2      Obesity
# 2   49  Female  Northeast        Married                     2       Normal
#
#   Smoking_Status Employment_Status Income_Level  Income_Lakhs  \
# 0     No Smoking          Salaried         <10L             6
# 1        Regular          Salaried         <10L             6
# 2     No Smoking     Self-Employed    10L - 25L            20
#
#        Medical History Insurance_Plan  Annual_Premium_Amount
# 0             Diabetes         Bronze                   9053
# 1             Diabetes         Bronze                  16339
# 2  High blood pressure         Silver                  18164

# %%
df.shape
# Out:
# (50000, 13)

# %%
df.columns = df.columns.str.replace(" ","_").str.lower()
df.head(3)
# Out:
#    age  gender     region marital_status  number_of_dependants bmi_category  \
# 0   26    Male  Northwest      Unmarried                     0       Normal
# 1   29  Female  Southeast        Married                     2      Obesity
# 2   49  Female  Northeast        Married                     2       Normal
#
#   smoking_status employment_status income_level  income_lakhs  \
# 0     No Smoking          Salaried         <10L             6
# 1        Regular          Salaried         <10L             6
# 2     No Smoking     Self-Employed    10L - 25L            20
#
#        medical_history insurance_plan  annual_premium_amount
# 0             Diabetes         Bronze                   9053
# 1             Diabetes         Bronze                  16339
# 2  High blood pressure         Silver                  18164

# %% [markdown]
# <h2 align="center" style="color:blue">Exploratory Data Analysis & Data Cleaning</h2>

# %% [markdown]
# ### Handle Missing Values

# %%
df.isna().sum()
# Out:
# age                       0
# gender                    0
# region                    0
# marital_status            0
# number_of_dependants      0
# bmi_category              0
# smoking_status           11
# employment_status         2
# income_level             13
# income_lakhs              0
# medical_history           0
# insurance_plan            0
# annual_premium_amount     0
# dtype: int64

# %%
df.dropna(inplace=True)
df.isna().sum()
# Out:
# age                      0
# gender                   0
# region                   0
# marital_status           0
# number_of_dependants     0
# bmi_category             0
# smoking_status           0
# employment_status        0
# income_level             0
# income_lakhs             0
# medical_history          0
# insurance_plan           0
# annual_premium_amount    0
# dtype: int64

# %% [markdown]
# ### Handle Duplicates

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.drop_duplicates(inplace=True)
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.describe()
# Out:
#                 age  number_of_dependants  income_lakhs  annual_premium_amount
# count  49976.000000          49976.000000  49976.000000           49976.000000
# mean      34.591764              1.711842     23.021150           15766.810189
# std       15.000378              1.498195     24.221794            8419.995271
# min       18.000000             -3.000000      1.000000            3501.000000
# 25%       22.000000              0.000000      7.000000            8607.750000
# 50%       31.000000              2.000000     17.000000           13928.000000
# 75%       45.000000              3.000000     31.000000           22273.500000
# max      356.000000              5.000000    930.000000           43471.000000

# %% [markdown]
# #### Data Cleaning: number_of_dependants

# %%
df[df['number_of_dependants']<0]['number_of_dependants'].unique()
# Out:
# array([-3, -1])

# %% [markdown]
# We can see some negative values in number_of_dependants. We can replace them with positive numbers

# %%
df['number_of_dependants'] = df['number_of_dependants'].abs()

df.describe()
# Out:
#                 age  number_of_dependants  income_lakhs  annual_premium_amount
# count  49976.000000          49976.000000  49976.000000           49976.000000
# mean      34.591764              1.717284     23.021150           15766.810189
# std       15.000378              1.491953     24.221794            8419.995271
# min       18.000000              0.000000      1.000000            3501.000000
# 25%       22.000000              0.000000      7.000000            8607.750000
# 50%       31.000000              2.000000     17.000000           13928.000000
# 75%       45.000000              3.000000     31.000000           22273.500000
# max      356.000000              5.000000    930.000000           43471.000000

# %% [markdown]
# ## 1. Numeric Columns

# %% [markdown]
# ### Univariate Analysis: Numeric Columns

# %% [markdown]
# #### Box plots for numeric columns

# %%
numeric_columns = df.select_dtypes(include=['float64', 'int64']).columns
numeric_columns
# Out:
# Index(['age', 'number_of_dependants', 'income_lakhs', 'annual_premium_amount'], dtype='str')

# %%
for col in numeric_columns:
    sns.boxplot(x=df[col])
    plt.show()

# %% [markdown]
# ### Outlier Treatment: Age Column

# %%
df[df['age']>100]['age'].unique()
# Out:
# array([224, 124, 136, 203, 356])

# %%
df1 = df[df.age<=100]
df1.age.describe()
# Out:
# count    49918.000000
# mean        34.401839
# std         13.681600
# min         18.000000
# 25%         22.000000
# 50%         31.000000
# 75%         45.000000
# max         72.000000
# Name: age, dtype: float64

# %% [markdown]
# ### Outlier Treatment: Income Column

# %%
def get_iqr_bounds(col):
    Q1, Q3 = col.quantile([0.25, 0.75])
    IQR = Q3-Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    return lower_bound, upper_bound

lower, upper = get_iqr_bounds(df1['income_lakhs'])
lower, upper
# Out:
# (-29.0, 67.0)

# %%
df1[df1.income_lakhs>upper].shape
# Out:
# (3559, 13)

# %% [markdown]
# There are many legitimate records that we will get rid of if we use IQR bounds method. Hence after discussion with business we decided to use a simple quantile bound

# %%
quantile_thresold = df1.income_lakhs.quantile(0.999)
quantile_thresold
# Out:
# np.float64(100.0)

# %%
df1[df1.income_lakhs>quantile_thresold].shape
# Out:
# (10, 13)

# %%
df2 = df1[df1.income_lakhs<=quantile_thresold].copy()
df2.shape
# Out:
# (49908, 13)

# %%
fig, axs = plt.subplots(nrows=2, ncols=2, figsize=(10, 8))  # Adjust the size as necessary

for i, column in enumerate(numeric_columns):
    ax = axs[i//2, i%2]  # Determines the position of the subplot in the grid
    sns.histplot(df2[column], kde=True, ax=ax)
    ax.set_title(column)

plt.tight_layout()
plt.show()

# %%
df2.head(2)
# Out:
#    age  gender     region marital_status  number_of_dependants bmi_category  \
# 0   26    Male  Northwest      Unmarried                     0       Normal
# 1   29  Female  Southeast        Married                     2      Obesity
#
#   smoking_status employment_status income_level  income_lakhs medical_history  \
# 0     No Smoking          Salaried         <10L             6        Diabetes
# 1        Regular          Salaried         <10L             6        Diabetes
#
#   insurance_plan  annual_premium_amount
# 0         Bronze                   9053
# 1         Bronze                  16339

# %% [markdown]
# ### Bivariate Analysis: Numeric Columns

# %%
numeric_columns
# Out:
# Index(['age', 'number_of_dependants', 'income_lakhs', 'annual_premium_amount'], dtype='str')

# %%
numeric_features = ['age', 'income_lakhs', 'number_of_dependants']

fig, axes = plt.subplots(1, len(numeric_features), figsize=(18, 6))  # Adjust figure size as necessary

for ax, column in zip(axes, numeric_features):
    sns.scatterplot(x=df2[column], y=df2['annual_premium_amount'], ax=ax)
    ax.set_title(f'{column} vs. Annual Premium Amount')
    ax.set_xlabel(column)
    ax.set_ylabel('Annual Premium Amount')

plt.tight_layout()  # Adjust layout
plt.show()

# %% [markdown]
# ## 2. Categorical Columns

# %%
categorical_cols = ['gender', 'region', 'marital_status', 'bmi_category', 'smoking_status', 'employment_status', 'income_level', 'medical_history', 'insurance_plan']
for col in categorical_cols:
    print(col, ":", df2[col].unique())
# Out:
# gender : <StringArray>
# ['Male', 'Female']
# Length: 2, dtype: str
# region : <StringArray>
# ['Northwest', 'Southeast', 'Northeast', 'Southwest']
# Length: 4, dtype: str
# marital_status : <StringArray>
# ['Unmarried', 'Married']
# Length: 2, dtype: str
# bmi_category : <StringArray>
# ['Normal', 'Obesity', 'Overweight', 'Underweight']
# Length: 4, dtype: str
# smoking_status : <StringArray>
# [    'No Smoking',        'Regular',     'Occasional',      'Smoking=0',
#  'Does Not Smoke',    'Not Smoking']
# Length: 6, dtype: str
# employment_status : <StringArray>
# ['Salaried', 'Self-Employed', 'Freelancer']
# Length: 3, dtype: str
# income_level : <StringArray>
# ['<10L', '10L - 25L', '> 40L', '25L - 40L']
# Length: 4, dtype: str
# medical_history : <StringArray>
# [                           'Diabetes',                 'High blood pressure',
#                           'No Disease',      'Diabetes & High blood pressure',
#                              'Thyroid',                       'Heart disease',
#  'High blood pressure & Heart disease',                  'Diabetes & Thyroid',
#             'Diabetes & Heart disease']
# Length: 9, dtype: str
# insurance_plan : <StringArray>
# ['Bronze', 'Silver', 'Gold']
# Length: 3, dtype: str

# %%
df2['smoking_status'].replace({
    'Not Smoking': 'No Smoking',
    'Does Not Smoke': 'No Smoking',
    'Smoking=0': 'No Smoking'
}, inplace=True)

df2['smoking_status'].unique()
# Out:
# /var/folders/js/zv7tkyc14d72g2r660k1l18m0000gn/T/ipykernel_2232/263445883.py:1: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# Such inplace method never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' instead, to perform the operation inplace on the original object, or try to avoid an inplace operation using 'df[col] = df[col].method(value)'.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html
#   df2['smoking_status'].replace({
# <StringArray>
# [    'No Smoking',        'Regular',     'Occasional',      'Smoking=0',
#  'Does Not Smoke',    'Not Smoking']
# Length: 6, dtype: str

# %% [markdown]
# ### Univariate Analysis

# %%
df2.head(2)
# Out:
#    age  gender     region marital_status  number_of_dependants bmi_category  \
# 0   26    Male  Northwest      Unmarried                     0       Normal
# 1   29  Female  Southeast        Married                     2      Obesity
#
#   smoking_status employment_status income_level  income_lakhs medical_history  \
# 0     No Smoking          Salaried         <10L             6        Diabetes
# 1        Regular          Salaried         <10L             6        Diabetes
#
#   insurance_plan  annual_premium_amount
# 0         Bronze                   9053
# 1         Bronze                  16339

# %%
pct_count = df2['gender'].value_counts(normalize=True)*100
pct_count
# Out:
# gender
# Male      54.963132
# Female    45.036868
# Name: proportion, dtype: float64

# %%
sns.barplot(x=pct_count.index, y=pct_count.values)
# Out:
# <Axes: xlabel='gender'>

# %%
fig, axes = plt.subplots(3, 3, figsize=(18, 18))  # Adjust figure size as necessary
axes = axes.flatten()  # Flatten the 2D array of axes into 1D for easier iteration

for ax, column in zip(axes, categorical_cols):
    # Calculate the percentage distribution of each category
    category_counts = df2[column].value_counts(normalize=True) * 100  # normalize=True gives the relative frequencies
    
    # Plotting the distribution using barplot
    sns.barplot(x=category_counts.index, y=category_counts.values, ax=ax)
    ax.set_title(f'Percentage Distribution of {column}')
    ax.set_ylabel('Percentage of Policyholders (%)')
    ax.set_xlabel(column)  # Set xlabel to the column name for clarity

plt.tight_layout()  # Adjusts plot parameters for better fit in the figure window
plt.show()

# %% [markdown]
# ### Bivariate Analysis

# %%
# Cross-tabulation of gender and smoking status
crosstab = pd.crosstab(df2['income_level'], df2['insurance_plan'])
print(crosstab)

# Plotting the crosstab
crosstab.plot(kind='bar', stacked=True)
plt.title('Income vs Plan')
plt.ylabel('Count')
plt.show()
# Out:
# insurance_plan  Bronze  Gold  Silver
# income_level
# 10L - 25L         5307  3880    5182
# 25L - 40L         3683  2840    3750
# <10L             12226   931    5486
# > 40L              329  3653    2641

# %%
sns.heatmap(crosstab, annot=True, cmap='coolwarm',fmt="d")
plt.title('Heatmap of Income vs Plan')
plt.show()

# %% [markdown]
# <h2 align="center" style="color:blue">Feature Engineering</h2>

# %%
df2.head(2)
# Out:
#    age  gender     region marital_status  number_of_dependants bmi_category  \
# 0   26    Male  Northwest      Unmarried                     0       Normal
# 1   29  Female  Southeast        Married                     2      Obesity
#
#   smoking_status employment_status income_level  income_lakhs medical_history  \
# 0     No Smoking          Salaried         <10L             6        Diabetes
# 1        Regular          Salaried         <10L             6        Diabetes
#
#   insurance_plan  annual_premium_amount
# 0         Bronze                   9053
# 1         Bronze                  16339

# %% [markdown]
# ### Calculate Risk Score

# %%
# Define the risk scores for each condition
risk_scores = {
    "diabetes": 6,
    "heart disease": 8,
    "high blood pressure":6,
    "thyroid": 5,
    "no disease": 0,
    "none":0
}

df2[['disease1', 'disease2']] = df2['medical_history'].str.split(" & ", expand=True).apply(lambda x: x.str.lower())
df2['disease1'].fillna('none', inplace=True)
df2['disease2'].fillna('none', inplace=True)
df2['total_risk_score'] = 0

for disease in ['disease1', 'disease2']:
    df2['total_risk_score'] += df2[disease].map(risk_scores)

# Normalize the risk score to a range of 0 to 1
max_score = df2['total_risk_score'].max()
min_score = df2['total_risk_score'].min()
df2['normalized_risk_score'] = (df2['total_risk_score'] - min_score) / (max_score - min_score)
df2.head(2)
# Out:
# /var/folders/js/zv7tkyc14d72g2r660k1l18m0000gn/T/ipykernel_2232/59644619.py:12: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# Such inplace method never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' instead, to perform the operation inplace on the original object, or try to avoid an inplace operation using 'df[col] = df[col].method(value)'.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html
#   df2['disease1'].fillna('none', inplace=True)
# /var/folders/js/zv7tkyc14d72g2r660k1l18m0000gn/T/ipykernel_2232/59644619.py:13: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# Such inplace method never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' instead, to perform the operation inplace on the original object, or try to avoid an inplace operation using 'df[col] = df[col].method(value)'.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html
#   df2['disease2'].fillna('none', inplace=True)
#    age  gender     region marital_status  number_of_dependants bmi_category  \
# 0   26    Male  Northwest      Unmarried                     0       Normal
# 1   29  Female  Southeast        Married                     2      Obesity
#
#   smoking_status employment_status income_level  income_lakhs medical_history  \
# 0     No Smoking          Salaried         <10L             6        Diabetes
# 1        Regular          Salaried         <10L             6        Diabetes
#
#   insurance_plan  annual_premium_amount  disease1 disease2  total_risk_score  \
# 0         Bronze                   9053  diabetes      NaN               NaN
# 1         Bronze                  16339  diabetes      NaN               NaN
#
#    normalized_risk_score
# 0                    NaN
# 1                    NaN

# %% [markdown]
# ### Encode Text Columns

# %%
df2['insurance_plan'] = df2['insurance_plan'].map({'Bronze': 1, 'Silver': 2, 'Gold': 3})

# %%
df2.income_level.unique()
# Out:
# <StringArray>
# ['<10L', '10L - 25L', '> 40L', '25L - 40L']
# Length: 4, dtype: str

# %%
df2['income_level'] = df2['income_level'].map({'<10L':1, '10L - 25L': 2, '25L - 40L':3, '> 40L':4})

# %%
nominal_cols = ['gender', 'region', 'marital_status', 'bmi_category', 'smoking_status', 'employment_status']
df3 = pd.get_dummies(df2, columns=nominal_cols, drop_first=True, dtype=int)
df3.head(3)
# Out:
#    age  number_of_dependants  income_level  income_lakhs      medical_history  \
# 0   26                     0             1             6             Diabetes
# 1   29                     2             1             6             Diabetes
# 2   49                     2             2            20  High blood pressure
#
#    insurance_plan  annual_premium_amount             disease1 disease2  \
# 0               1                   9053             diabetes      NaN
# 1               1                  16339             diabetes      NaN
# 2               2                  18164  high blood pressure      NaN
#
#    total_risk_score  ...  bmi_category_Obesity  bmi_category_Overweight  \
# 0               NaN  ...                     0                        0
# 1               NaN  ...                     1                        0
# 2               NaN  ...                     0                        0
#
#    bmi_category_Underweight  smoking_status_No Smoking  \
# 0                         0                          1
# 1                         0                          0
# 2                         0                          1
#
#    smoking_status_Not Smoking  smoking_status_Occasional  \
# 0                           0                          0
# 1                           0                          0
# 2                           0                          0
#
#    smoking_status_Regular  smoking_status_Smoking=0  \
# 0                       0                         0
# 1                       1                         0
# 2                       0                         0
#
#    employment_status_Salaried  employment_status_Self-Employed
# 0                           1                                0
# 1                           1                                0
# 2                           0                                1
#
# [3 rows x 26 columns]

# %%
df3.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 49908 entries, 0 to 49999
# Data columns (total 26 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   age                              49908 non-null  int64
#  1   number_of_dependants             49908 non-null  int64
#  2   income_level                     49908 non-null  int64
#  3   income_lakhs                     49908 non-null  int64
#  4   medical_history                  49908 non-null  str
#  5   insurance_plan                   49908 non-null  int64
#  6   annual_premium_amount            49908 non-null  int64
#  7   disease1                         49908 non-null  str
#  8   disease2                         4768 non-null   str
#  9   total_risk_score                 4768 non-null   float64
#  10  normalized_risk_score            4768 non-null   float64
#  11  gender_Male                      49908 non-null  int64
#  12  region_Northwest                 49908 non-null  int64
#  13  region_Southeast                 49908 non-null  int64
#  14  region_Southwest                 49908 non-null  int64
#  15  marital_status_Unmarried         49908 non-null  int64
#  16  bmi_category_Obesity             49908 non-null  int64
#  17  bmi_category_Overweight          49908 non-null  int64
#  18  bmi_category_Underweight         49908 non-null  int64
#  19  smoking_status_No Smoking        49908 non-null  int64
#  20  smoking_status_Not Smoking       49908 non-null  int64
#  21  smoking_status_Occasional        49908 non-null  int64
#  22  smoking_status_Regular           49908 non-null  int64
#  23  smoking_status_Smoking=0         49908 non-null  int64
#  24  employment_status_Salaried       49908 non-null  int64
#  25  employment_status_Self-Employed  49908 non-null  int64
# dtypes: float64(2), int64(21), str(3)
# memory usage: 10.3 MB

# %% [markdown]
# ### Feature Selection

# %%
df4 = df3.drop(['medical_history','disease1', 'disease2', 'total_risk_score'], axis=1)
df4.head(3)
# Out:
#    age  number_of_dependants  income_level  income_lakhs  insurance_plan  \
# 0   26                     0             1             6               1
# 1   29                     2             1             6               1
# 2   49                     2             2            20               2
#
#    annual_premium_amount  normalized_risk_score  gender_Male  \
# 0                   9053                    NaN            1
# 1                  16339                    NaN            0
# 2                  18164                    NaN            0
#
#    region_Northwest  region_Southeast  ...  bmi_category_Obesity  \
# 0                 1                 0  ...                     0
# 1                 0                 1  ...                     1
# 2                 0                 0  ...                     0
#
#    bmi_category_Overweight  bmi_category_Underweight  \
# 0                        0                         0
# 1                        0                         0
# 2                        0                         0
#
#    smoking_status_No Smoking  smoking_status_Not Smoking  \
# 0                          1                           0
# 1                          0                           0
# 2                          1                           0
#
#    smoking_status_Occasional  smoking_status_Regular  \
# 0                          0                       0
# 1                          0                       1
# 2                          0                       0
#
#    smoking_status_Smoking=0  employment_status_Salaried  \
# 0                         0                           1
# 1                         0                           1
# 2                         0                           0
#
#    employment_status_Self-Employed
# 0                                0
# 1                                0
# 2                                1
#
# [3 rows x 22 columns]

# %% [markdown]
# ### Calculate VIF for Multicolinearity

# %%
df4.columns
# Out:
# Index(['age', 'number_of_dependants', 'income_level', 'income_lakhs',
#        'insurance_plan', 'annual_premium_amount', 'normalized_risk_score',
#        'gender_Male', 'region_Northwest', 'region_Southeast',
#        'region_Southwest', 'marital_status_Unmarried', 'bmi_category_Obesity',
#        'bmi_category_Overweight', 'bmi_category_Underweight',
#        'smoking_status_No Smoking', 'smoking_status_Not Smoking',
#        'smoking_status_Occasional', 'smoking_status_Regular',
#        'smoking_status_Smoking=0', 'employment_status_Salaried',
#        'employment_status_Self-Employed'],
#       dtype='str')

# %%
cm = df4.corr()

plt.figure(figsize=(20,12))
sns.heatmap(cm, annot=True)
plt.xticks(rotation=45, ha='right')
plt.yticks(rotation=0)
plt.tight_layout()
plt.show()

# %%
X = df4.drop('annual_premium_amount', axis='columns')
y = df4['annual_premium_amount']

from sklearn.preprocessing import MinMaxScaler

cols_to_scale = ['age','number_of_dependants', 'income_level',  'income_lakhs', 'insurance_plan']
scaler = MinMaxScaler()

X[cols_to_scale] = scaler.fit_transform(X[cols_to_scale])
X.describe()
# Out:
#                 age  number_of_dependants  income_level  income_lakhs  \
# count  49908.000000          49908.000000  49908.000000  49908.000000
# mean       0.303733              0.343528      0.365900      0.221110
# std        0.253363              0.298406      0.349711      0.223946
# min        0.000000              0.000000      0.000000      0.000000
# 25%        0.074074              0.000000      0.000000      0.060606
# 50%        0.240741              0.400000      0.333333      0.161616
# 75%        0.500000              0.600000      0.666667      0.303030
# max        1.000000              1.000000      1.000000      1.000000
#
#        insurance_plan  normalized_risk_score   gender_Male  region_Northwest  \
# count    49908.000000            4768.000000  49908.000000       49908.00000
# mean         0.397401               0.536703      0.549631           0.20093
# std          0.392459               0.414978      0.497536           0.40070
# min          0.000000               0.000000      0.000000           0.00000
# 25%          0.000000               0.333333      0.000000           0.00000
# 50%          0.500000               0.333333      1.000000           0.00000
# 75%          0.500000               1.000000      1.000000           0.00000
# max          1.000000               1.000000      1.000000           1.00000
#
#        region_Southeast  region_Southwest  ...  bmi_category_Obesity  \
# count      49908.000000      49908.000000  ...          49908.000000
# mean           0.350385          0.303038  ...              0.143183
# std            0.477095          0.459576  ...              0.350263
# min            0.000000          0.000000  ...              0.000000
# 25%            0.000000          0.000000  ...              0.000000
# 50%            0.000000          0.000000  ...              0.000000
# 75%            1.000000          1.000000  ...              0.000000
# max            1.000000          1.000000  ...              1.000000
#
#        bmi_category_Overweight  bmi_category_Underweight  \
# count             49908.000000              49908.000000
# mean                  0.231245                  0.155326
# std                   0.421633                  0.362219
# min                   0.000000                  0.000000
# 25%                   0.000000                  0.000000
# 50%                   0.000000                  0.000000
# 75%                   0.000000                  0.000000
# max                   1.000000                  1.000000
#
#        smoking_status_No Smoking  smoking_status_Not Smoking  \
# count               49908.000000                 49908.00000
# mean                    0.547427                     0.00016
# std                     0.497751                     0.01266
# min                     0.000000                     0.00000
# 25%                     0.000000                     0.00000
# 50%                     1.000000                     0.00000
# 75%                     1.000000                     0.00000
# max                     1.000000                     1.00000
#
#        smoking_status_Occasional  smoking_status_Regular  \
# count               49908.000000            49908.000000
# mean                    0.138274                0.313857
# std                     0.345191                0.464064
# min                     0.000000                0.000000
# 25%                     0.000000                0.000000
# 50%                     0.000000                0.000000
# 75%                     0.000000                1.000000
# max                     1.000000                1.000000
#
#        smoking_status_Smoking=0  employment_status_Salaried  \
# count               49908.00000                49908.000000
# mean                    0.00016                    0.419412
# std                     0.01266                    0.493468
# min                     0.00000                    0.000000
# 25%                     0.00000                    0.000000
# 50%                     0.00000                    0.000000
# 75%                     0.00000                    1.000000
# max                     1.00000                    1.000000
#
#        employment_status_Self-Employed
# count                     49908.000000
# mean                          0.272041
# std                           0.445015
# min                           0.000000
# 25%                           0.000000
# 50%                           0.000000
# 75%                           1.000000
# max                           1.000000
#
# [8 rows x 21 columns]

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

def calculate_vif(data):
    vif_df = pd.DataFrame()
    vif_df['Column'] = data.columns
    vif_df['VIF'] = [variance_inflation_factor(data.values,i) for i in range(data.shape[1])]
    return vif_df

# %%
calculate_vif(X)
# Out:
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# Cell In[90], line 1
# ----> 1 calculate_vif(X)
#
# Cell In[89], line 6, in calculate_vif(data)
#       3 def calculate_vif(data):
#       4     vif_df = pd.DataFrame()
#       5     vif_df['Column'] = data.columns
# ----> 6     vif_df['VIF'] = [variance_inflation_factor(data.values,i) for i in range(data.shape[1])]
#       7     return vif_df
#
# File ~/Downloads/project_1_datacleaning_&_EDA_resources/.venv/lib/python3.12/site-packages/statsmodels/stats/outliers_influence.py:222, in variance_inflation_factor(exog, exog_idx, standardize)
#     219 else:
#     220     working = exog
# --> 222 cond_num = np.linalg.cond(working)
#     223 if cond_num > 1e4:
#     224     warnings.warn(
#     225         f"The design matrix is poorly conditioned (condition number={cond_num:.2e}). "
#     226         "VIF calculations may be numerically unstable.",
#     227         UserWarning,
#     228         stacklevel=2,
#     229     )
#
# File ~/Downloads/project_1_datacleaning_&_EDA_resources/.venv/lib/python3.12/site-packages/numpy/linalg/_linalg.py:1999, in cond(x, p)
#    1997     raise LinAlgError("cond is not defined on empty arrays")
#    1998 if p is None or p in {2, -2}:
# -> 1999     s = svd(x, compute_uv=False)
#    2000     with errstate(all='ignore'):
#    2001         if p == -2:
#
# File ~/Downloads/project_1_datacleaning_&_EDA_resources/.venv/lib/python3.12/site-packages/numpy/linalg/_linalg.py:1850, in svd(a, full_matrices, compute_uv, hermitian)
#    1846 signature = 'D->d' if isComplexType(t) else 'd->d'
#    1847 with errstate(call=_raise_linalgerror_svd_nonconvergence,
#    1848               invalid='call', over='ignore', divide='ignore',
#    1849               under='ignore'):
# -> 1850     s = _umath_linalg.svd(a, signature=signature)
#    1851 s = s.astype(_realType(result_t), copy=False)
#    1852 return s
#
# File ~/Downloads/project_1_datacleaning_&_EDA_resources/.venv/lib/python3.12/site-packages/numpy/linalg/_linalg.py:153, in _raise_linalgerror_svd_nonconvergence(err, flag)
#     152 def _raise_linalgerror_svd_nonconvergence(err, flag):
# --> 153     raise LinAlgError("SVD did not converge")
#
# LinAlgError: SVD did not converge

# %%
calculate_vif(X.drop('income_level', axis="columns"))
# Out:
#                              Column       VIF
# 0                               age  4.545825
# 1              number_of_dependants  4.526598
# 2                      income_lakhs  2.480563
# 3                    insurance_plan  3.445682
# 4             normalized_risk_score  2.687326
# 5                       gender_Male  2.409980
# 6                  region_Northwest  2.100789
# 7                  region_Southeast  2.919775
# 8                  region_Southwest  2.668314
# 9          marital_status_Unmarried  3.393718
# 10             bmi_category_Obesity  1.352748
# 11          bmi_category_Overweight  1.549907
# 12         bmi_category_Underweight  1.302636
# 13        smoking_status_Occasional  1.272744
# 14           smoking_status_Regular  1.777024
# 15       employment_status_Salaried  2.374628
# 16  employment_status_Self-Employed  2.132810

# %%
# we will drop income_lakhs due to high VIF value
X_reduced = X.drop('income_level', axis="columns")

# %% [markdown]
# <h2 align="center" style="color:blue">Model Training</h2>

# %%
X_train, X_test, y_train, y_test = train_test_split(X_reduced, y, test_size=0.30, random_state=10)

# shape of the X_train, X_test, y_train, y_test features
print("x train: ",X_train.shape)
print("x test: ",X_test.shape)
print("y train: ",y_train.shape)
print("y test: ",y_test.shape)
# Out:
# x train:  (34935, 17)
# x test:  (14973, 17)
# y train:  (34935,)
# y test:  (14973,)

# %% [markdown]
# ### Linear Regression Model

# %%
model_lr = LinearRegression()
model_lr.fit(X_train, y_train)
test_score = model_lr.score(X_test, y_test)
train_score = model_lr.score(X_train, y_train)
train_score, test_score
# Out:
# (0.9282143576916762, 0.9280547230217837)

# %%
y_pred = model_lr.predict(X_test)

mse_lr = mean_squared_error(y_test, y_pred)
rmse_lr = np.sqrt(mse_lr)
print("Linear Regression ==> MSE: ", mse_lr, "RMSE: ", rmse_lr)
# Out:
# Linear Regression ==> MSE:  5165611.913027982 RMSE:  2272.798256121291

# %%
X_test.shape
# Out:
# (14973, 17)

# %%
np.set_printoptions(suppress=True, precision=6)
model_lr.coef_
# Out:
# array([11160.926462,  -676.443991,  -514.229816, 12557.012936,
#         4810.357702,   168.646662,   -35.719292,    39.96513 ,
#          -24.652929,  -935.760611,  3387.911455,  1599.362268,
#          391.171304,   735.912278,  2234.804712,   155.984674,
#          415.903973])

# %%
feature_importance = model_lr.coef_

# Create a DataFrame for easier handling
coef_df = pd.DataFrame(feature_importance, index=X_train.columns, columns=['Coefficients'])

# Sort the coefficients for better visualization
coef_df = coef_df.sort_values(by='Coefficients', ascending=True)

# Plotting
plt.figure(figsize=(8, 4))
plt.barh(coef_df.index, coef_df['Coefficients'], color='steelblue')
plt.xlabel('Coefficient Value')
plt.title('Feature Importance in Linear Regression')
plt.show()

# %% [markdown]
# ### Ridge Regression Model

# %%
model_rg = Ridge(alpha=1)
model_rg.fit(X_train, y_train)
test_score = model_rg.score(X_test, y_test)
train_score = model_rg.score(X_train, y_train)
train_score, test_score
# Out:
# (0.9282143198366275, 0.9280541644640345)

# %%
y_pred = model_rg.predict(X_test)

mse_lr = mean_squared_error(y_test, y_pred)
rmse_lr = np.sqrt(mse_lr)
print("Ridge Regression ==> MSE: ", mse_lr, "RMSE: ", rmse_lr)
# Out:
# Ridge Regression ==> MSE:  5165652.017016523 RMSE:  2272.8070787060924

# %% [markdown]
# ### XGBoost

# %%
from xgboost import XGBRegressor

model_xgb = XGBRegressor(n_estimators=20, max_depth=3)
model_xgb.fit(X_train, y_train)
model_xgb.score(X_test, y_test)
# Out:
# 0.9782300559809473

# %%
y_pred = model_xgb.predict(X_test)

mse_lr = mean_squared_error(y_test, y_pred)
rmse_lr = np.sqrt(mse_lr)
print("XGBoost Regression ==> MSE: ", mse_lr, "RMSE: ", rmse_lr)
# Out:
# XGBoost Regression ==> MSE:  1563064.1356043513 RMSE:  1250.2256338774819

# %%
model_xgb = XGBRegressor()
param_grid = {
    'n_estimators': [20, 40, 50],
    'learning_rate': [0.01, 0.1, 0.2],
    'max_depth': [3, 4, 5],
}
random_search = RandomizedSearchCV(model_xgb, param_grid, n_iter=10, cv=3, scoring='r2', random_state=42, n_jobs=-1)
random_search.fit(X_train, y_train)
random_search.best_score_
# Out:
# 0.9809474553641963

# %%
random_search.best_params_
# Out:
# {'n_estimators': 50, 'max_depth': 5, 'learning_rate': 0.1}

# %%
best_model = random_search.best_estimator_

# %%
feature_importance = best_model.feature_importances_

# Create a DataFrame for easier handling
coef_df = pd.DataFrame(feature_importance, index=X_train.columns, columns=['Coefficients'])

# Sort the coefficients for better visualization
coef_df = coef_df.sort_values(by='Coefficients', ascending=True)

# Plotting
plt.figure(figsize=(8, 4))
plt.barh(coef_df.index, coef_df['Coefficients'], color='steelblue')
plt.xlabel('Coefficient Value')
plt.title('Feature Importance in XGBoost')
plt.show()

# %%
y_pred = best_model.predict(X_test)

residuals = y_pred - y_test
residuals_pct = (residuals / y_test) * 100

results_df = pd.DataFrame({
    'actual': y_test, 
    'predicted': y_pred, 
    'diff': residuals, 
    'diff_pct': residuals_pct
})
results_df.head()
# Out:
#        actual     predicted         diff   diff_pct
# 3598    20554  20334.953125  -219.046875  -1.065714
# 35794   29647  29378.779297  -268.220703  -0.904714
# 43608   20560  20618.185547    58.185547   0.283004
# 42730    5018   7352.829590  2334.829590  46.529087
# 18936    8929   8203.291992  -725.708008  -8.127540

# %%
sns.histplot(results_df['diff_pct'], kde=True)
plt.title('Distribution of Residuals')
plt.xlabel('Diff PCT')
plt.ylabel('Frequency')
plt.show()

# %%
X_test.shape
# Out:
# (14973, 17)

# %%
extreme_error_threshold = 10  # You can adjust this threshold based on your domain knowledge or requirements
extreme_results_df = results_df[np.abs(results_df['diff_pct']) > extreme_error_threshold]
extreme_results_df.head()
# Out:
#        actual     predicted         diff   diff_pct
# 42730    5018   7352.829590  2334.829590  46.529087
# 20029    5140   6670.849121  1530.849121  29.783057
# 4294     9631   7053.477539 -2577.522461 -26.762771
# 44419    4687   6670.849121  1983.849121  42.326629
# 6707     8826  10047.326172  1221.326172  13.837822

# %%
extreme_results_df.shape
# Out:
# (4487, 4)

# %%
extreme_errors_pct = extreme_results_df.shape[0]*100/X_test.shape[0]
extreme_errors_pct
# Out:
# 29.967274427302478

# %% [markdown]
# We have 30% extreme errors which means for 30% customers we will either overcharge or undercharge by 10% or more

# %%
extreme_results_df[abs(extreme_results_df.diff_pct)>50].sort_values("diff_pct",ascending=False)
# Out:
#        actual    predicted         diff   diff_pct
# 36269    3501  6565.852051  3064.852051  87.542189
# 48801    3516  6565.852051  3049.852051  86.742095
# 42342    3521  6565.852051  3044.852051  86.476911
# 18564    3523  6565.852051  3042.852051  86.371049
# 7988     3527  6565.852051  3038.852051  86.159684
# ...       ...          ...          ...        ...
# 32671    4656  6994.980957  2338.980957  50.235845
# 14798    4371  6565.852051  2194.852051  50.213957
# 13736    4371  6565.852051  2194.852051  50.213957
# 10107    4710  7073.240723  2363.240723  50.174962
# 16908    4699  7053.477539  2354.477539  50.105928
#
# [549 rows x 4 columns]

# %% [markdown]
# There will be about 549 customers whom we will overcharge or underchage by more than 50%

# %%
extreme_errors_df = X_test.loc[extreme_results_df.index]
extreme_errors_df.head(2)
# Out:
#             age  number_of_dependants  income_lakhs  insurance_plan  \
# 42730  0.092593                   0.2      0.131313             0.0
# 20029  0.018519                   0.2      0.030303             0.0
#
#        normalized_risk_score  gender_Male  region_Northwest  region_Southeast  \
# 42730               0.428571            1                 0                 0
# 20029               0.000000            0                 1                 0
#
#        region_Southwest  marital_status_Unmarried  bmi_category_Obesity  \
# 42730                 0                         1                     0
# 20029                 0                         1                     0
#
#        bmi_category_Overweight  bmi_category_Underweight  \
# 42730                        1                         0
# 20029                        0                         1
#
#        smoking_status_Occasional  smoking_status_Regular  \
# 42730                          0                       0
# 20029                          0                       0
#
#        employment_status_Salaried  employment_status_Self-Employed
# 42730                           0                                0
# 20029                           1                                0

# %%
for feature in X_test.columns:
    plt.figure(figsize=(10, 4))
    sns.histplot(extreme_errors_df[feature], color='red', label='Extreme Errors', kde=True)
    sns.histplot(X_test[feature], color='blue', label='Overall', alpha=0.5, kde=True)
    plt.legend()
    plt.title(f'Distribution of {feature} for Extreme Errors vs Overall')
    plt.show()

# %% [markdown]
# ### Reverse Scaling

# %%
extreme_errors_df['income_level']=-1

# %%
df_reversed = pd.DataFrame()
df_reversed[cols_to_scale] = scaler.inverse_transform(extreme_errors_df[cols_to_scale])
df_reversed.head()
# Out:
#     age  number_of_dependants  income_level  income_lakhs  insurance_plan
# 0  23.0                   1.0          -2.0          14.0             1.0
# 1  19.0                   1.0          -2.0           4.0             1.0
# 2  18.0                   1.0          -2.0           3.0             1.0
# 3  21.0                   0.0          -2.0          25.0             1.0
# 4  24.0                   1.0          -2.0           8.0             2.0

# %%
df_reversed.describe()
# Out:
#                age  number_of_dependants  income_level  income_lakhs  \
# count  4487.000000           4487.000000        4487.0   4487.000000
# mean     21.804992              0.739247          -2.0     21.182527
# std       3.172355              0.968855           0.0     20.598596
# min      18.000000              0.000000          -2.0      1.000000
# 25%      20.000000              0.000000          -2.0      6.000000
# 50%      22.000000              0.000000          -2.0     15.000000
# 75%      24.000000              1.000000          -2.0     30.000000
# max      60.000000              5.000000          -2.0    100.000000
#
#        insurance_plan
# count     4487.000000
# mean         1.302429
# std          0.563135
# min          1.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max          3.000000

# %%
sns.histplot(df_reversed.age)
# Out:
# <Axes: xlabel='age', ylabel='Count'>

# %% [markdown]
# This shows that majority of the extreme errors are coming from young age group (i.e. <25 years of age). We need to may be build a separate model for this segment
